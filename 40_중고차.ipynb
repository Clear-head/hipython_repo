# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
import datetime
from re import findall, search, match
# %matplotlib inline

# %%
df = pd.read_csv('./data/Dubizzle_used_car_sales.csv')
df.head(2)
# Out:
#                            title  price_in_aed  kilometers  \
# 0  MITSUBISHI PAJERO 3.5L / 2013         26000      167390
# 1            chevrolet silverado        110000       39000
#
#            body_condition    mechanical_condition seller_type body_type  \
# 0  Perfect inside and out  Perfect inside and out      Dealer       SUV
# 1  Perfect inside and out  Perfect inside and out      Dealer       SUV
#
#   no_of_cylinders       transmission_type        regional_specs    horsepower  \
# 0               6  Automatic Transmission             GCC Specs       Unknown
# 1               8  Automatic Transmission  North American Specs  400 - 500 HP
#
#   fuel_type   steering_side    year   color   emirate        motors_trim  \
# 0  Gasoline  Left Hand Side  2013.0  Silver     Dubai                GLS
# 1  Gasoline  Left Hand Side  2018.0   White   Sharjah  1500 High Country
#
#       company      model date_posted
# 0  mitsubishi     pajero  13/05/2022
# 1   chevrolet  silverado  14/01/2022

# %%
df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 9965 non-null   object
#  1   price_in_aed          9970 non-null   int64
#  2   kilometers            9970 non-null   int64
#  3   body_condition        9970 non-null   object
#  4   mechanical_condition  9970 non-null   object
#  5   seller_type           9970 non-null   object
#  6   body_type             9970 non-null   object
#  7   no_of_cylinders       9889 non-null   object
#  8   transmission_type     9970 non-null   object
#  9   regional_specs        9970 non-null   object
#  10  horsepower            9970 non-null   object
#  11  fuel_type             9970 non-null   object
#  12  steering_side         9970 non-null   object
#  13  year                  9000 non-null   float64
#  14  color                 9970 non-null   object
#  15  emirate               9970 non-null   object
#  16  motors_trim           9942 non-null   object
#  17  company               9970 non-null   object
#  18  model                 9970 non-null   object
#  19  date_posted           9970 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.5+ MB
# (None,
#         price_in_aed    kilometers         year
#  count  9.970000e+03  9.970000e+03  9000.000000
#  mean   2.480496e+05  9.894896e+04  2015.626444
#  std    4.536549e+05  1.154300e+06     4.735991
#  min    6.000000e+03  0.000000e+00  1953.000000
#  25%    5.100000e+04  2.314350e+04  2014.000000
#  50%    1.040000e+05  7.600000e+04  2016.000000
#  75%    2.340000e+05  1.330828e+05  2019.000000
#  max    1.499900e+07  1.150000e+08  2021.000000)

# %% [markdown]
# --------------------
# ## 결측치 확인

# %%
for i in df.columns:
    print(f"{i} = {df[i].isnull().sum()}")
# Out:
# title = 5
# price_in_aed = 0
# kilometers = 0
# body_condition = 0
# mechanical_condition = 0
# seller_type = 0
# body_type = 0
# no_of_cylinders = 81
# transmission_type = 0
# regional_specs = 0
# horsepower = 0
# fuel_type = 0
# steering_side = 0
# year = 970
# color = 0
# emirate = 0
# motors_trim = 28
# company = 0
# model = 0
# date_posted = 0

# %%
non_na_like = ['unknown', 'Unknown', 'NONE', 'none', 'null', 'Null', 'NA', 'na', 'N/A', 'n/a', 'nan', 'NaN', "NAN", '-', '', ' ']


def ch_null():
    result = {}

    for col in df.columns:
        col_data = df[col]
        # NaN 
        na_count = col_data.isnull().sum()
        # 의미상 결측치 
        unknown_count = col_data.astype(str).str.strip().isin(non_na_like).sum()
        result[col] = {
            'na_count': na_count,
            'non_na_like_count': unknown_count
        }

    summary = pd.DataFrame(result).T
    print(summary)

ch_null()
# Out:
#                       na_count  non_na_like_count
# title                        5                  5
# price_in_aed                 0                  0
# kilometers                   0                  0
# body_condition               0                  0
# mechanical_condition         0                  0
# seller_type                  0                  0
# body_type                    0                  0
# no_of_cylinders             81                138
# transmission_type            0                  0
# regional_specs               0                  0
# horsepower                   0                814
# fuel_type                    0                  0
# steering_side                0                  0
# year                       970                970
# color                        0                  0
# emirate                      0                  0
# motors_trim                 28                 28
# company                      0                  0
# model                        0                  0
# date_posted                  0                  0

# %%
def to_none(data):
    if data in non_na_like:
        return None
    else:
        return data

# %%
for i in df.columns:
    df[i] = df[i].apply(to_none)

# %%
ch_null()
# Out:
#                       na_count  non_na_like_count
# title                        5                  5
# price_in_aed                 0                  0
# kilometers                   0                  0
# body_condition               0                  0
# mechanical_condition         0                  0
# seller_type                  0                  0
# body_type                    0                  0
# no_of_cylinders            138                 81
# transmission_type            0                  0
# regional_specs               0                  0
# horsepower                 814                  0
# fuel_type                    0                  0
# steering_side                0                  0
# year                       970                970
# color                        0                  0
# emirate                      0                  0
# motors_trim                 28                 28
# company                      0                  0
# model                        0                  0
# date_posted                  0                  0

# %% [markdown]
# -------------
# ## year 결측치 처리
# year 의 결측치가 제일 많기 때문에 먼저 처리.
# 삭제하기 전에 title 에 해당 연도가 작성 되어있는 경우가 있으니 타이틀에서 년도를 가져와 채워 넣는다.
# 그래도 안되는 부분은 삭제.

# %%
def find_year(row):
    existing_year = row['year']
    title_text = str(row['title'])

    if pd.isna(existing_year) or existing_year in non_na_like:
        found_years = findall(r'(19[5-9][0-9]|20[0-1][0-9]|202[0-4]|2025)', title_text)
        
        if found_years:
            return float(found_years[0])
        else:
            return None
    else:
        return existing_year

df["year"] = df.apply(find_year, axis=1)

# %%
df[df["year"].isna()]
# Out:
#                                                   title  price_in_aed  \
# 394              Toyota Land Cruiser GXR 3.3 Twin Turbo        340000
# 441   A4 Advanced 35 TFSI 150hp (Ref#06147) *AVAILAB...        175000
# 466                                      volkswagen id4        115000
# 508     Brand New BMW 760Li M Class Dealer warranty GCC        539000
# 536   A4 Advanced 35 TFSI 150hp (Ref#06062) *AVAILAB...        175000
# ...                                                 ...           ...
# 9390          LEXUS LX 600 F SPORT LAUNCH EDITION 1/100        650000
# 9473  Panamera 4 EHybrid. Aventurine Green/ Satin wh...        675000
# 9682                                     Lotus Evora GT        399000
# 9735  Mercedes G63 Amg Gcc Gergash Warranty And serv...        999000
# 9936           BMW 730Li Pure Excellence (REF#  128396)        374000
#
#       kilometers          body_condition    mechanical_condition  \
# 394            0  Perfect inside and out  Perfect inside and out
# 441         5000  Perfect inside and out  Perfect inside and out
# 466            0  Perfect inside and out  Perfect inside and out
# 508           10  Perfect inside and out  Perfect inside and out
# 536         5000  Perfect inside and out  Perfect inside and out
# ...          ...                     ...                     ...
# 9390         100  Perfect inside and out  Perfect inside and out
# 9473        2000  Perfect inside and out  Perfect inside and out
# 9682        5345  Perfect inside and out  Perfect inside and out
# 9735           0  Perfect inside and out  Perfect inside and out
# 9936        4535  Perfect inside and out  Perfect inside and out
#
#                          seller_type  body_type no_of_cylinders  \
# 394                            Owner        SUV               6
# 441   Dealership/Certified Pre-Owned      Sedan               4
# 466                           Dealer  Crossover             NaN
# 508                           Dealer      Sedan              12
# 536   Dealership/Certified Pre-Owned      Sedan               4
# ...                              ...        ...             ...
# 9390                           Owner        SUV               6
# 9473                           Owner      Sedan               6
# 9682  Dealership/Certified Pre-Owned      Coupe               6
# 9735                          Dealer        SUV               8
# 9936  Dealership/Certified Pre-Owned      Sedan               4
#
#            transmission_type regional_specs    horsepower fuel_type  \
# 394   Automatic Transmission      GCC Specs  150 - 200 HP    Diesel
# 441   Automatic Transmission      GCC Specs  150 - 200 HP  Gasoline
# 466   Automatic Transmission          Other          None  Electric
# 508   Automatic Transmission      GCC Specs  500 - 600 HP  Gasoline
# 536   Automatic Transmission      GCC Specs  150 - 200 HP  Gasoline
# ...                      ...            ...           ...       ...
# 9390  Automatic Transmission      GCC Specs  400 - 500 HP  Gasoline
# 9473  Automatic Transmission      GCC Specs  400 - 500 HP    Hybrid
# 9682  Automatic Transmission      GCC Specs  500 - 600 HP  Gasoline
# 9735  Automatic Transmission      GCC Specs  500 - 600 HP  Gasoline
# 9936  Automatic Transmission      GCC Specs  200 - 300 HP  Gasoline
#
#        steering_side  year   color     emirate   motors_trim        company  \
# 394   Left Hand Side   NaN   White       Dubai           GXR         toyota
# 441   Left Hand Side   NaN    Grey   Abu Dhabi         Other           audi
# 466   Left Hand Side   NaN    Grey       Dubai         Crozz     volkswagen
# 508   Left Hand Side   NaN    Blue       Dubai  760Li xDrive            bmw
# 536   Left Hand Side   NaN   White   Abu Dhabi         Other           audi
# ...              ...   ...     ...         ...           ...            ...
# 9390  Left Hand Side   NaN  Silver       Dubai           NaN          lexus
# 9473  Left Hand Side   NaN   Green       Dubai         Other        porsche
# 9682  Left Hand Side   NaN   Green       Dubai         Other          lotus
# 9735  Left Hand Side   NaN   Green       Dubai      G 63 AMG  mercedes-benz
# 9936  Left Hand Side   NaN   Black       Dubai         730Li            bmw
#
#              model date_posted
# 394   land-cruiser  13/05/2022
# 441             a4  02/03/2022
# 466            id4  11/05/2022
# 508       7-series  15/01/2022
# 536             a4  17/03/2022
# ...            ...         ...
# 9390         lx600  13/05/2022
# 9473      panamera  07/05/2022
# 9682         evora  14/03/2022
# 9735       g-class  08/04/2022
# 9936      7-series  07/04/2022
#
# [164 rows x 20 columns]

# %% [markdown]
# ------------
# ## moters_trim 결측치 처리
# ### title에서 moters_trim 의 값이 포함된 경우도 존재하기 때문에 title에서 가져와 결측치 채우기

# %% [markdown]
# ### 확인 결과:   렉서스 LX600 모델이 제일 많다 하지만 LX600 의 트림은 타이틀에 존재하기 때문에 채워넣을 수 있다.

# %%
df[df["motors_trim"].isnull()]
# Out:
#                                                   title  price_in_aed  \
# 494                   Lexus LX600 F Sport  2022 0km GCC        739000
# 657      2022 LX600 VIP Launch Edition  DEALER WARRANTY        729000
# 671   (LHD) Lexus LX600 F Sport 3.5P AT MY2022  Blac...        800000
# 937                     Brand new Lexus LX600 signature        650000
# 956    Lexus LX600 VIP Launch Edition 2022 - For Export        769000
# 1025  2022 Mercedes Benz GLE 53 AMG 4Matic+ | Brand ...        589000
# 1200  BRAND NEW - LEXUS LX 600 - F SPORT - 2022- GCC...        735000
# 1374  LX600 3.5L VIP KURO (GRANDEUR+) 4-SEATER*EXPOR...        950000
# 2378  2022 Lexus LX600 Signature/Sonic Titanium / GC...        680000
# 2494  2022 Model,Gcc , Under Warranty and Contract S...        695000
# 2698                 Lx600 VIP BRAND NEW FROM ALFUTTAIM        690000
# 2763                       Lexus LX600 F SPORT 2022 GCC        640000
# 2906          Lexus LX 600 F Sport Launch Edition 1/100        663999
# 3109                            mercedes-benz gle-class        230000
# 3338        LX600 3.5L F-SPORT FF 5-SEATER*EXPORT ONLY*        750000
# 4370                 Lexus LX 600 2022 - Under Warranty        728500
# 4734                                        Genesis G80         62000
# 4774  Brand New 2022 Lexus LX600 Signature Dealer Wa...        680000
# 4796  Only whatsap pls, Lexus LX 600 F- Sport lunch ...        720000
# 4943  2022 Lexus LX 600 F-Sport Launch Edition | Bra...        699000
# 5124                         Lx600 F Sport GCC alfutaim        640000
# 5844  LEXUS LX600  SIGNATURE, PETROL, 2022, GCC SPEC...        665000
# 6807  2022  LEXUS  LX600  LAUNCH  EDITION  VIP  BRAN...        790000
# 7043                       !! 2022 !! Lexus LX600 VIP 慢        719000
# 7216  2022 MITSUBISHI XPANDER | 1.5 H/L 2WD EURO 4 D...         57000
# 8466                                        lexus lx600        750000
# 9020  Lexus LX600 - 2022 - LAUNCH EDITION-Vip Brand ...        860000
# 9390          LEXUS LX 600 F SPORT LAUNCH EDITION 1/100        650000
#
#       kilometers          body_condition    mechanical_condition seller_type  \
# 494            0  Perfect inside and out  Perfect inside and out      Dealer
# 657            0  Perfect inside and out  Perfect inside and out      Dealer
# 671            0  Perfect inside and out  Perfect inside and out      Dealer
# 937          100  Perfect inside and out  Perfect inside and out       Owner
# 956            0  Perfect inside and out  Perfect inside and out      Dealer
# 1025           0  Perfect inside and out  Perfect inside and out      Dealer
# 1200           0  Perfect inside and out  Perfect inside and out      Dealer
# 1374           0  Perfect inside and out  Perfect inside and out      Dealer
# 2378           0  Perfect inside and out  Perfect inside and out      Dealer
# 2494           0  Perfect inside and out  Perfect inside and out      Dealer
# 2698           0  Perfect inside and out  Perfect inside and out       Owner
# 2763           0  Perfect inside and out  Perfect inside and out      Dealer
# 2906         100  Perfect inside and out  Perfect inside and out       Owner
# 3109      115000  Perfect inside and out  Perfect inside and out      Dealer
# 3338           0  Perfect inside and out  Perfect inside and out      Dealer
# 4370           0  Perfect inside and out  Perfect inside and out      Dealer
# 4734       40000  Perfect inside and out  Perfect inside and out      Dealer
# 4774           0  Perfect inside and out  Perfect inside and out      Dealer
# 4796           0  Perfect inside and out  Perfect inside and out       Owner
# 4943           1  Perfect inside and out  Perfect inside and out      Dealer
# 5124        2300  Perfect inside and out  Perfect inside and out       Owner
# 5844           0  Perfect inside and out  Perfect inside and out      Dealer
# 6807          50  Perfect inside and out  Perfect inside and out      Dealer
# 7043           0  Perfect inside and out  Perfect inside and out      Dealer
# 7216           0  Perfect inside and out  Perfect inside and out      Dealer
# 8466         100  Perfect inside and out  Perfect inside and out       Owner
# 9020           0  Perfect inside and out  Perfect inside and out      Dealer
# 9390         100  Perfect inside and out  Perfect inside and out       Owner
#
#      body_type no_of_cylinders       transmission_type        regional_specs  \
# 494        SUV               6  Automatic Transmission             GCC Specs
# 657        SUV               6  Automatic Transmission             GCC Specs
# 671        SUV               6  Automatic Transmission                 Other
# 937        SUV               6  Automatic Transmission             GCC Specs
# 956        SUV               8  Automatic Transmission             GCC Specs
# 1025       SUV               6  Automatic Transmission             GCC Specs
# 1200       SUV               6  Automatic Transmission             GCC Specs
# 1374       SUV               6  Automatic Transmission             GCC Specs
# 2378       SUV               6  Automatic Transmission             GCC Specs
# 2494       SUV               5  Automatic Transmission             GCC Specs
# 2698       SUV               6  Automatic Transmission             GCC Specs
# 2763       SUV               6  Automatic Transmission             GCC Specs
# 2906       SUV               6  Automatic Transmission             GCC Specs
# 3109       SUV               8  Automatic Transmission             GCC Specs
# 3338       SUV               6  Automatic Transmission             GCC Specs
# 4370       SUV               6  Automatic Transmission             GCC Specs
# 4734     Sedan               6  Automatic Transmission  North American Specs
# 4774       SUV               6  Automatic Transmission             GCC Specs
# 4796       SUV               6  Automatic Transmission             GCC Specs
# 4943       SUV               6  Automatic Transmission             GCC Specs
# 5124       SUV               6  Automatic Transmission             GCC Specs
# 5844       SUV               6  Automatic Transmission             GCC Specs
# 6807       SUV               6  Automatic Transmission             GCC Specs
# 7043       SUV               6  Automatic Transmission             GCC Specs
# 7216       SUV               4  Automatic Transmission             GCC Specs
# 8466       SUV               6  Automatic Transmission             GCC Specs
# 9020       SUV               6  Automatic Transmission             GCC Specs
# 9390       SUV               6  Automatic Transmission             GCC Specs
#
#             horsepower fuel_type   steering_side    year        color  \
# 494               None  Gasoline  Left Hand Side  2022.0       Silver
# 657       400 - 500 HP  Gasoline  Left Hand Side  2022.0         Grey
# 671       400 - 500 HP  Gasoline  Left Hand Side  2022.0        Black
# 937       400 - 500 HP  Gasoline  Left Hand Side     NaN  Other Color
# 956       500 - 600 HP  Gasoline  Left Hand Side  2022.0         Gold
# 1025      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 1200      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 1374      400 - 500 HP  Gasoline  Left Hand Side     NaN        Black
# 2378      400 - 500 HP  Gasoline  Left Hand Side  2022.0       Silver
# 2494      150 - 200 HP  Gasoline  Left Hand Side  2022.0         Grey
# 2698      400 - 500 HP  Gasoline  Left Hand Side     NaN         Gold
# 2763      300 - 400 HP  Gasoline  Left Hand Side  2022.0         Grey
# 2906      400 - 500 HP  Gasoline  Left Hand Side     NaN       Silver
# 3109              None  Gasoline  Left Hand Side  2018.0        White
# 3338      400 - 500 HP  Gasoline  Left Hand Side     NaN         Grey
# 4370      400 - 500 HP  Gasoline  Left Hand Side  2022.0       Silver
# 4734              None  Gasoline  Left Hand Side  2017.0       Silver
# 4774      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 4796      300 - 400 HP  Gasoline  Left Hand Side     NaN        White
# 4943      400 - 500 HP  Gasoline  Left Hand Side  2022.0       Silver
# 5124      400 - 500 HP  Gasoline  Left Hand Side     NaN        White
# 5844      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 6807      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 7043      400 - 500 HP  Gasoline  Left Hand Side  2022.0        White
# 7216  Less than 150 HP  Gasoline  Left Hand Side  2022.0        Black
# 8466      400 - 500 HP  Gasoline  Left Hand Side     NaN        White
# 9020      400 - 500 HP  Gasoline  Left Hand Side  2022.0        Black
# 9390      400 - 500 HP  Gasoline  Left Hand Side     NaN       Silver
#
#          emirate motors_trim        company      model date_posted
# 494        Dubai         NaN          lexus      lx600  04/04/2022
# 657        Dubai         NaN          lexus      lx600  05/05/2022
# 671        Dubai         NaN          lexus      lx600  22/04/2022
# 937      Sharjah         NaN          lexus      lx600  27/04/2022
# 956        Dubai         NaN          lexus      lx600  25/04/2022
# 1025       Dubai         NaN  mercedes-benz  gle-class  25/01/2022
# 1200       Dubai         NaN          lexus      lx600  25/04/2022
# 1374       Dubai         NaN          lexus      lx600  30/03/2022
# 2378       Dubai         NaN          lexus      lx600  15/04/2022
# 2494       Dubai         NaN          lexus      lx600  19/03/2022
# 2698       Dubai         NaN          lexus      lx600  30/04/2022
# 2763   Abu Dhabi         NaN          lexus      lx600  26/04/2022
# 2906       Dubai         NaN          lexus      lx600  13/04/2022
# 3109     Sharjah         NaN  mercedes-benz  gle-class  02/03/2022
# 3338       Dubai         NaN          lexus      lx600  15/03/2022
# 4370       Dubai         NaN          lexus      lx600  21/04/2022
# 4734     Sharjah         NaN        genesis        g80  21/02/2022
# 4774       Dubai         NaN          lexus      lx600  10/05/2022
# 4796       Dubai         NaN          lexus      lx600  07/04/2022
# 4943       Dubai         NaN          lexus      lx600  19/04/2022
# 5124       Dubai         NaN          lexus      lx600  01/05/2022
# 5844       Dubai         NaN          lexus      lx600  26/04/2022
# 6807       Dubai         NaN          lexus      lx600  17/03/2022
# 7043       Dubai         NaN          lexus      lx600  16/03/2022
# 7216       Dubai         NaN     mitsubishi    xpander  24/03/2022
# 8466      Al Ain         NaN          lexus      lx600  10/05/2022
# 9020       Dubai         NaN          lexus      lx600  16/04/2022
# 9390       Dubai         NaN          lexus      lx600  13/05/2022

# %%
def lx(row):
    if not row["model"] == "lx600":
        return row["motors_trim"]
    
    if not type(row["title"]) == str:
        return row["motors_trim"]
    
    title_text = row["title"].lower()
    if pd.isna(row["motors_trim"]):
        m_trim = findall(r'(standard|premium|sport|vip|signature|f-sport)', title_text)

        if m_trim:
            return "".join(m_trim)
        else:
            return None
    else:
        return row["motors_trim"]

# %%
df["motors_trim"] = df.apply(lx, axis=1)

# %%
ch_null()
# Out:
#                       na_count  non_na_like_count
# title                        5                  5
# price_in_aed                 0                  0
# kilometers                   0                  0
# body_condition               0                  0
# mechanical_condition         0                  0
# seller_type                  0                  0
# body_type                    0                  0
# no_of_cylinders            138                 81
# transmission_type            0                  0
# regional_specs               0                  0
# horsepower                 814                  0
# fuel_type                    0                  0
# steering_side                0                  0
# year                       164                164
# color                        0                  0
# emirate                      0                  0
# motors_trim                  7                  4
# company                      0                  0
# model                        0                  0
# date_posted                  0                  0

# %% [markdown]
# ----------
# ## 실린더와 마력

# %%
ch_null()
# Out:
#                       na_count  non_na_like_count
# title                        5                  5
# price_in_aed                 0                  0
# kilometers                   0                  0
# body_condition               0                  0
# mechanical_condition         0                  0
# seller_type                  0                  0
# body_type                    0                  0
# no_of_cylinders            138                 81
# transmission_type            0                  0
# regional_specs               0                  0
# horsepower                 814                  0
# fuel_type                    0                  0
# steering_side                0                  0
# year                       164                164
# color                        0                  0
# emirate                      0                  0
# motors_trim                  7                  4
# company                      0                  0
# model                        0                  0
# date_posted                  0                  0

# %%
df[["no_of_cylinders", "horsepower"]]
# Out:
#                                                   title  price_in_aed  \
# 164   Brand New  Renault Zoe - Full Electric - REG/I...        120000
# 204                                         Honda pilot         25000
# 337   Polestar 2 SRSM Barley Colored Nappa Leather P...        159650
# 417   2022 VOLKSWAGEN ID.6 CROZZ PRO LONG RANGE RWD ...        185999
# 437      Toyota Coaster 2014 Gcc Engine Diesel 30 Seats         77000
# ...                                                 ...           ...
# 8978  Audi Q5 - Low Milage - S-LINE - METALLIC GREY ...        100000
# 9295  Volkswagen ID.4 X - PURE PLUS - WHT - 2yr Gold...        139000
# 9392         PURE+CROZZ SKY VIEW ROOF LONG RANGE 555KMS        112000
# 9465                                         S560 Coupe        380000
# 9720               HINO 300 TRUCK M/T DSL-*EXPORT ONLY*         80000
#
#       kilometers                      body_condition     mechanical_condition  \
# 164            0              Perfect inside and out   Perfect inside and out
# 204       220000              Perfect inside and out   Perfect inside and out
# 337           12              Perfect inside and out   Perfect inside and out
# 417            9              Perfect inside and out   Perfect inside and out
# 437        87000              Perfect inside and out   Perfect inside and out
# ...          ...                                 ...                      ...
# 8978       66000  A bit of wear & tear, all repaired  Minor faults, all fixed
# 9295          41              Perfect inside and out   Perfect inside and out
# 9392           0              Perfect inside and out   Perfect inside and out
# 9465       69000       No accidents, very few faults   Perfect inside and out
# 9720           0              Perfect inside and out   Perfect inside and out
#
#      seller_type      body_type no_of_cylinders       transmission_type  \
# 164       Dealer      Hatchback             NaN  Automatic Transmission
# 204        Owner            SUV            None  Automatic Transmission
# 337       Dealer            SUV             NaN  Automatic Transmission
# 417       Dealer            SUV             NaN  Automatic Transmission
# 437       Dealer            Van            None     Manual Transmission
# ...          ...            ...             ...                     ...
# 8978       Owner            SUV            None  Automatic Transmission
# 9295      Dealer      Crossover             NaN  Automatic Transmission
# 9392      Dealer      Crossover             NaN  Automatic Transmission
# 9465       Owner          Coupe            None  Automatic Transmission
# 9720      Dealer  Utility Truck            None     Manual Transmission
#
#       regional_specs        horsepower fuel_type   steering_side    year  \
# 164        GCC Specs  Less than 150 HP  Electric  Left Hand Side  2020.0
# 204        GCC Specs              None  Gasoline  Left Hand Side  2011.0
# 337            Other      300 - 400 HP  Electric  Left Hand Side  2022.0
# 417   European Specs              None  Electric  Left Hand Side  2022.0
# 437        GCC Specs              None    Diesel  Left Hand Side  2014.0
# ...              ...               ...       ...             ...     ...
# 8978       GCC Specs              None  Gasoline  Left Hand Side  2016.0
# 9295           Other      200 - 300 HP  Electric  Left Hand Side     NaN
# 9392       GCC Specs      200 - 300 HP  Electric  Left Hand Side  2021.0
# 9465       GCC Specs              None  Gasoline  Left Hand Side  2018.0
# 9720       GCC Specs              None    Diesel  Left Hand Side  2019.0
#
#          color emirate  motors_trim        company           model date_posted
# 164      White   Dubai        Other        renault           other  14/12/2021
# 204   Burgundy   Dubai        Other          honda           pilot  07/05/2022
# 337      White   Dubai        Other       polestar               2  12/05/2022
# 417       Blue   Dubai        Other     volkswagen             id6  12/05/2022
# 437      White   Dubai        Other         toyota           other  23/03/2022
# ...        ...     ...          ...            ...             ...         ...
# 8978      Grey   Dubai       S-line           audi              q5  11/05/2022
# 9295     White   Dubai        Other     volkswagen             id4  28/04/2022
# 9392      Blue   Dubai        Crozz     volkswagen             id4  06/04/2022
# 9465     White   Dubai  S 560 Coupe  mercedes-benz   s-class-coupe  26/04/2022
# 9720    Yellow   Dubai        Other     other-make  heavy-vehicles  26/06/2021
#
# [138 rows x 20 columns]

# %% [markdown]
# --------------
# ### 타이틀이 너무 난잡하고 뒤의 정보와 겹치는 부분이 많기 때문에 제거

# %%
df = df.drop("title", axis=1)

# %% [markdown]
# --------------
# ## date_post 타입변경
# ### date_posted 가 string 형식이기 때문에 date 형식으로 변경

# %%
def chdt(data):
    return datetime.datetime.strptime(data.strftime("%Y-%m-%d"), "%Y-%m-%d")

# %%
df["date_posted"] = pd.to_datetime(df["date_posted"])
df["date_posted"] = df["date_posted"].apply(chdt)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17700\4056154445.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["date_posted"] = pd.to_datetime(df["date_posted"])

# %%
df.head(2)
# Out:
#    price_in_aed  kilometers          body_condition    mechanical_condition  \
# 0         26000      167390  Perfect inside and out  Perfect inside and out
# 1        110000       39000  Perfect inside and out  Perfect inside and out
#
#   seller_type body_type no_of_cylinders       transmission_type  \
# 0      Dealer       SUV               6  Automatic Transmission
# 1      Dealer       SUV               8  Automatic Transmission
#
#          regional_specs    horsepower fuel_type   steering_side    year  \
# 0             GCC Specs          None  Gasoline  Left Hand Side  2013.0
# 1  North American Specs  400 - 500 HP  Gasoline  Left Hand Side  2018.0
#
#     color   emirate        motors_trim     company      model date_posted
# 0  Silver     Dubai                GLS  mitsubishi     pajero  2022-05-13
# 1   White   Sharjah  1500 High Country   chevrolet  silverado  2022-01-14

# %% [markdown]
# ### 이상치 확인

# %% [markdown]
# 1. 중고 판매 게시일 보다 차량 제조년도가 더 늦은 경우 존재 -> 삭제

# %%
def asd(data):
    if str(data)[:-2].isnumeric():
        data = str(data)[:-2] if len(str(data)) > 4 else str(data)
        return datetime.datetime.strptime(data, "%Y")
    else:
        return None


df[df["year"].apply(asd).dt.year > df["date_posted"].dt.year]
# Out:
#       price_in_aed  kilometers          body_condition  \
# 30         1090000           0  Perfect inside and out
# 282        1595000           0  Perfect inside and out
# 325         520000          70  Perfect inside and out
# 769          36500           0  Perfect inside and out
# 794        1990000         100  Perfect inside and out
# ...            ...         ...                     ...
# 9452        357000           0  Perfect inside and out
# 9716       1395000           0  Perfect inside and out
# 9807        729000           0  Perfect inside and out
# 9963         79000          25  Perfect inside and out
# 9967        679000         100  Perfect inside and out
#
#         mechanical_condition seller_type body_type no_of_cylinders  \
# 30    Perfect inside and out      Dealer     Wagon               8
# 282   Perfect inside and out      Dealer       SUV              12
# 325   Perfect inside and out      Dealer     Sedan               8
# 769   Perfect inside and out      Dealer       SUV               4
# 794   Perfect inside and out      Dealer     Sedan              12
# ...                      ...         ...       ...             ...
# 9452  Perfect inside and out      Dealer       SUV               6
# 9716  Perfect inside and out      Dealer     Sedan              12
# 9807  Perfect inside and out      Dealer       SUV               8
# 9963  Perfect inside and out      Dealer       SUV               4
# 9967  Perfect inside and out      Dealer       SUV               8
#
#            transmission_type  regional_specs        horsepower fuel_type  \
# 30    Automatic Transmission       GCC Specs      500 - 600 HP  Gasoline
# 282   Automatic Transmission  European Specs      600 - 700 HP  Gasoline
# 325   Automatic Transmission       GCC Specs      400 - 500 HP  Gasoline
# 769   Automatic Transmission           Other  Less than 150 HP  Gasoline
# 794   Automatic Transmission       GCC Specs      500 - 600 HP  Gasoline
# ...                      ...             ...               ...       ...
# 9452  Automatic Transmission           Other      400 - 500 HP    Diesel
# 9716  Automatic Transmission       GCC Specs      600 - 700 HP  Gasoline
# 9807  Automatic Transmission  European Specs      500 - 600 HP  Gasoline
# 9963  Automatic Transmission       GCC Specs      150 - 200 HP  Gasoline
# 9967  Automatic Transmission           Other      400 - 500 HP  Gasoline
#
#        steering_side    year        color     emirate   motors_trim  \
# 30    Left Hand Side  2022.0        White       Dubai      G 63 AMG
# 282   Left Hand Side  2022.0  Other Color       Dubai         Other
# 325   Left Hand Side  2022.0        White       Dubai  750Li xDrive
# 769   Left Hand Side  2022.0         Grey       Dubai           GLX
# 794   Left Hand Side  2025.0        Black       Dubai      Standard
# ...              ...     ...          ...         ...           ...
# 9452  Left Hand Side  2022.0        White       Dubai         Other
# 9716  Left Hand Side  2022.0        White       Dubai         Other
# 9807  Left Hand Side  2023.0         Grey   Abu Dhabi           110
# 9963  Left Hand Side  2022.0        Brown       Dubai       Comfort
# 9967  Left Hand Side  2022.0        Black       Dubai           SVR
#
#             company              model date_posted
# 30    mercedes-benz            g-class  2021-12-18
# 282         maybach              other  2021-11-27
# 325             bmw           7-series  2021-12-08
# 769          suzuki              dzire  2021-08-22
# 794     rolls-royce              ghost  2022-04-23
# ...             ...                ...         ...
# 9452         toyota       land-cruiser  2021-12-11
# 9716  mercedes-benz            s-class  2021-12-27
# 9807     land-rover           defender  2022-04-19
# 9963         jetour                x70  2021-10-20
# 9967     land-rover  range-rover-sport  2021-12-14
#
# [65 rows x 19 columns]

# %%
df = df.drop(index = df[df["year"].apply(asd).dt.year > df["date_posted"].dt.year].index, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9905 entries, 0 to 9969
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price_in_aed          9905 non-null   int64
#  1   kilometers            9905 non-null   int64
#  2   body_condition        9905 non-null   object
#  3   mechanical_condition  9905 non-null   object
#  4   seller_type           9905 non-null   object
#  5   body_type             9905 non-null   object
#  6   no_of_cylinders       9767 non-null   object
#  7   transmission_type     9905 non-null   object
#  8   regional_specs        9905 non-null   object
#  9   horsepower            9091 non-null   object
#  10  fuel_type             9905 non-null   object
#  11  steering_side         9905 non-null   object
#  12  year                  9741 non-null   float64
#  13  color                 9905 non-null   object
#  14  emirate               9905 non-null   object
#  15  motors_trim           9898 non-null   object
#  16  company               9905 non-null   object
#  17  model                 9905 non-null   object
#  18  date_posted           9905 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(15)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 그리고 년월일 컬럼으로 각각 분리

# %%
df["year_posted"] = df["date_posted"].dt.year
df["month_posted"] = df["date_posted"].dt.month
df["day_posted"] = df["date_posted"].dt.day
df = df.drop("date_posted", axis=1)
df
# Out:
#       price_in_aed  kilometers                 body_condition  \
# 0            26000      167390         Perfect inside and out
# 1           110000       39000         Perfect inside and out
# 2            78000      200000         Perfect inside and out
# 3           899000       27000         Perfect inside and out
# 4            33000       69000         Perfect inside and out
# ...            ...         ...                            ...
# 9964        225000           0         Perfect inside and out
# 9965        215000      105777         Perfect inside and out
# 9966         90000       55640         Perfect inside and out
# 9968         18900      140000  No accidents, very few faults
# 9969         77700       86000         Perfect inside and out
#
#         mechanical_condition seller_type             body_type  \
# 0     Perfect inside and out      Dealer                   SUV
# 1     Perfect inside and out      Dealer                   SUV
# 2     Perfect inside and out      Dealer                 Sedan
# 3     Perfect inside and out      Dealer  Hard Top Convertible
# 4     Perfect inside and out       Owner                 Wagon
# ...                      ...         ...                   ...
# 9964  Perfect inside and out      Dealer                   SUV
# 9965  Perfect inside and out      Dealer                   SUV
# 9966  Perfect inside and out       Owner                   SUV
# 9968  Perfect inside and out       Owner                 Sedan
# 9969  Perfect inside and out      Dealer             Crossover
#
#      no_of_cylinders       transmission_type        regional_specs  \
# 0                  6  Automatic Transmission             GCC Specs
# 1                  8  Automatic Transmission  North American Specs
# 2                  6  Automatic Transmission             GCC Specs
# 3                  8  Automatic Transmission             GCC Specs
# 4                  4     Manual Transmission             GCC Specs
# ...              ...                     ...                   ...
# 9964               6  Automatic Transmission             GCC Specs
# 9965               8  Automatic Transmission             GCC Specs
# 9966               8  Automatic Transmission             GCC Specs
# 9968               4  Automatic Transmission             GCC Specs
# 9969               6     Manual Transmission             GCC Specs
#
#             horsepower  ...   steering_side    year   color   emirate  \
# 0                 None  ...  Left Hand Side  2013.0  Silver     Dubai
# 1         400 - 500 HP  ...  Left Hand Side  2018.0   White   Sharjah
# 2         400 - 500 HP  ...  Left Hand Side  2014.0    Blue   Sharjah
# 3         600 - 700 HP  ...  Left Hand Side  2018.0     Red     Dubai
# 4     Less than 150 HP  ...  Left Hand Side  2020.0   White     Dubai
# ...                ...  ...             ...     ...     ...       ...
# 9964      200 - 300 HP  ...  Left Hand Side  2021.0   White     Dubai
# 9965      500 - 600 HP  ...  Left Hand Side  2015.0   White     Dubai
# 9966      400 - 500 HP  ...  Left Hand Side  2014.0   White     Dubai
# 9968      150 - 200 HP  ...  Left Hand Side  2013.0   White     Dubai
# 9969      200 - 300 HP  ...  Left Hand Side  2013.0  Orange     Dubai
#
#             motors_trim        company           model year_posted  \
# 0                   GLS     mitsubishi          pajero        2022
# 1     1500 High Country      chevrolet       silverado        2022
# 2                 E 300  mercedes-benz         e-class        2022
# 3              Standard        ferrari      488-spider        2022
# 4              Standard        renault          dokker        2022
# ...                 ...            ...             ...         ...
# 9964            Limited           jeep  grand-cherokee        2022
# 9965      Autobiography     land-rover     range-rover        2021
# 9966           Platinum       cadillac        escalade        2022
# 9968                 LS      chevrolet          malibu        2022
# 9969             Sahara           jeep        wrangler        2021
#
#       month_posted  day_posted
# 0                5          13
# 1                1          14
# 2                5           5
# 3                4          30
# 4                5          13
# ...            ...         ...
# 9964             2           1
# 9965            11          18
# 9966             5          11
# 9968             3           6
# 9969            12           4
#
# [9905 rows x 21 columns]

# %% [markdown]
# ------------
# ## 범주형 변수 원핫 인코딩
# ### 범주의 변수의 값이 전부 string 으로 되어있기 때문에 int 형으로 변환

# %%
# import re

# complier = re.compile("[a-zA-Z]")

# le = LabelEncoder()

# for i in df.columns:
#     if complier.search(str(df[i].iloc[0])):
#         df[i] = le.fit_transform(df[i])

# df
